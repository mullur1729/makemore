# %%
import torch
g = torch.Generator().manual_seed(2147483647)

A = torch.zeros((2,3),dtype=torch.int32)
B = torch.randint(0, 10, (5,5), generator=g)

# %%
B.stride()
# Out:
# (5, 1)

# %%
B
# Out:
# tensor([[1, 4, 9, 2, 3],
#         [0, 4, 6, 7, 7],
#         [1, 5, 6, 8, 1],
#         [4, 4, 9, 8, 0],
#         [3, 6, 6, 0, 9]])
